# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
from graph_tool.all import *

# %% [markdown]
# ## Load the wikipedia dataset

# %%
wikipedia_dataset="../data/wikipedia/pythonic_data/enwiki-07032015-linkgraph-wtitle.gt"

# %%
GG=load_graph(wikipedia_dataset)

# %% [markdown]
# ## Statistics

# %% [markdown]
# #### Size

# %%
GG.num_vertices()
# Out:
# 11571226

# %%
GG.num_edges()
# Out:
# 174686648

# %% [markdown]
# #### Degree distribution

# %%
freqs, bins=graph_tool.stats.vertex_hist(GG, deg='in')
plt.plot(np.log(bins[:-1]), np.log(freqs), 'go')
plt.title("in degree histogram")

# %%
freqs, bins=graph_tool.stats.vertex_hist(GG, deg='out')
plt.plot(np.log(bins[:-1]), np.log(freqs), 'go')
plt.title("out degree histogram")

# %% [markdown]
# ## Traverse the dataset

# %% [markdown]
# #### Access a wikipedia page with a title:

# %%
god_page=graph_tool.util.find_vertex(GG, GG.vertex_properties['title'], 'God')[0]
god_page
# Out:
# <Vertex object with index '2001504' at 0x7ff88079a5e8>

# %%
python_page=graph_tool.util.find_vertex(GG, GG.vertex_properties['title'], 'Python')[0]
python_page
# Out:
# <Vertex object with index '7293737' at 0x7ff88079a750>

# %% [markdown]
# #### Explore the neighbourhood of a page:

# %%
for nei in python_page.out_neighbours():
    print(GG.vertex_properties['title'][nei])
# Out:
# Python (genus)
# Pythonidae
# Python (mythology)
# Python of Aenus
# Python of Byzantium
# Python of Catana
# Python (programming language)
# CPython
# CMU Common Lisp
# PERQ
# Python (film)
# Python II
# Monty Python
# Python (Busch Gardens Tampa Bay)
# Python (Coney Island)
# Python (Efteling)
# Colt Python
# Python missile
# Armstrong Siddeley Python
# Python Automobile
# Pyton

# %% [markdown]
# #### Find out shortest path between two wikipedia articles

# %%
v=GG.vertex(np.random.randint(0, GG.num_vertices()))

# %%
GG.vertex_properties['title'][v]
# Out:
# 'Krittibas Ojha'

# %%
god=graph_tool.util.find_vertex(GG, GG.vertex_properties['title'], 'God')[0]

# %%
vertices, edges=graph_tool.topology.shortest_path(GG, source=v, target=god)

# %%
for v in vertices:
    print(GG.vertex_properties['title'][v], end='\t')
# Out:
# Krittibas Ojha	God

# %% [markdown]
# Test:

# %%
J=nx.read_gpickle("../data/visualization/medium_graph.gpickle")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-102-f6e3a5d7b378> in <module>()
# ----> 1 J=nx.read_gpickle("../data/visualization/medium_graph.gpickle")
#
# /usr/lib/python3/dist-packages/networkx/readwrite/gpickle.py in read_gpickle(path)
#
# /usr/lib/python3/dist-packages/networkx/utils/decorators.py in _open_file(func, *args, **kwargs)
#     261         # Finally, we call the original function, making sure to close the fobj.
#     262         try:
# --> 263             result = func(*new_args, **kwargs)
#     264         finally:
#     265             if close_fobj:
#
# /usr/lib/python3/dist-packages/networkx/readwrite/gpickle.py in read_gpickle(path)
#      93     .. [1] http://docs.python.org/library/pickle.html
#      94     """
# ---> 95     return pickle.load(path)
#      96
#      97 # fixture for nose tests
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0x92 in position 6: ordinal not in range(128)

# %% [markdown]
# ### Show is_planar
