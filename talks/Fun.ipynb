# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
# %matplotlib inline

# %% [markdown]
# ## Random walk:

# %%
    G=nx.read_gpickle("../data/airport/smaller_airportnet.pickle")

# %%
src='FRA'

# %%
def random_walk_ret_time(G, src=None):
    if not src:
        src=np.random.choice(G.nodes())
 
    time=1
    at=np.random.choice(G.neighbors(src))
    
    while at!=src:
        at=np.random.choice(G.neighbors(at))
        time+=1
    
    return time

def

# %%
import numpy as np
import networkx as nx
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
plt.ion()

G = nx.cycle_graph(10)



def rand_walk(n):
    global src
    nc=np.ones(G.number_of_nodes())
    src=np.random.choice(G.neighbors(src))
    nc[allnodes.index(src)]=0
    nodes.set_array(nc)
    return nodes,

def rw_on_graph(G): 
    fig = plt.figure(figsize=(8,8))
    pos=nx.circular_layout(G)

    src=np.random.choice(G.nodes())
    allnodes=G.nodes()

    nc=np.ones(G.number_of_nodes())
    nc[allnodes.index(src)]=0


    nodes = nx.draw_networkx_nodes(G,pos,node_color=nc)
    edges = nx.draw_networkx_edges(G,pos)

    anim = FuncAnimation(fig, rand_walk, interval=1000, blit=True)
    return

rw_on_graph(G)
